# %% [markdown]
# Hemos creado un segundo cuaderno para trabajar paralelamente en diferentes versiones de código, hasta conseguir la que resuelva nuestras necesidades.
#
# EL JUEGO DEL AHORCADO EN NAVIDAD:
# **¿Cuáles son sus premisas?**
